# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian-Ibrahim/SU-Machine-learning-1222785/blob/main/04_05_2023_ml_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([0.5,1,2,2.5,3.5,4,5,5.5,6])
y= np .array([1.5,2,1,2.5,2,3.5,2.5,3,4])

# %%
plt.scatter(x,y)
plt.grid(True)
plt.show()
